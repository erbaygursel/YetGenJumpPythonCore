# %% [markdown]
# Link paylaşımı var ama linkleri de text olarak okuyor. Değiştirmek gerek.

# %%
import openai
import pyttsx3
import speech_recognition as sr

# set up OpenAI API credentials
openai.api_key = "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"

engine = pyttsx3.init()

r = sr.Recognizer()
mic = sr.Microphone(device_index=1)

conversation = ""
user_name = "Simyacı"
bot_name = "PATRON AI"

while True:
    with mic as source:
        print("\nlistening...")
        r.adjust_for_ambient_noise(source, duration=0.2)
        audio = r.listen(source)
    print("no longer listening.\n")

    try:
        user_input = r.recognize_google(audio, language='tr-TR')
        print(user_input)
        if user_input.lower() in ["çıkış", "exit"]:
            break
    except:
        continue

    prompt = user_name + ": " + user_input + "\n" + bot_name+ ": "

    conversation += prompt  # allows for context

    # fetch response from OpenAI API
    response = openai.Completion.create(
        engine='text-davinci-002',
        prompt=conversation,
        max_tokens=100,
        n=1,
        stop=None,
        temperature=0.7,
    )

    response_str = response["choices"][0]["text"].replace("\n", "")
    response_str = response_str.split(user_name + ": ", 1)[0].split(bot_name + ": ", 1)[0]

    conversation += response_str + "\n"
    print(response_str)

    engine.say(response_str)
    engine.runAndWait()
# Out:
# listening...
# no longer listening.
#
# Merhaba
#  Merhaba!
#
# listening...
# no longer listening.
#
# kimsin Sen kimsin
#  Ben bir Zek robotuyum.
#
# listening...
# no longer listening.
#
#
# listening...
# no longer listening.
#
# çıkış

# %% [markdown]
# #Alternatif versiyon: Buton özelliği eklendi ama link paylaşımı yok.

# %%
import openai
import pyttsx3
import speech_recognition as sr
import tkinter as tk

# OpenAI API anahtarını ayarlayın
openai.api_key = "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"

# metin-konuşma motorunu başlatın
engine = pyttsx3.init()

# konuşma tanıma işlemini ayarlayın
r = sr.Recognizer()
mic = sr.Microphone(device_index=1)

# Tkinter penceresi oluşturun
window = tk.Tk()
window.title("OpenAI Bot")
window.geometry("400x400")

# metin kutularını oluşturun
user_text = tk.Text(window, height=5, width=50)
user_text.pack()
bot_text = tk.Text(window, height=5, width=50)
bot_text.pack()

# düğmeleri oluşturun
continue_button = tk.Button(window, text="Konuşmaya devam et")
continue_button.pack()
exit_button = tk.Button(window, text="Çıkış")
exit_button.pack()

conversation = ""
user_name = "You"
bot_name = "DAI"

def continue_conversation():
    global conversation
    with mic as source:
        print("\nlistening...")
        r.adjust_for_ambient_noise(source, duration=0.2)
        audio = r.listen(source)
    print("no longer listening.\n")

    try:
        user_input = r.recognize_google(audio, language='tr-TR')
        print(user_input)
        if user_input.lower() in ["çıkış", "exit"]:
            window.destroy()
            return
    except:
        user_input = ""

    prompt = user_name + ": " + user_input + "\n" + bot_name+ ": "

    conversation += prompt  # allows for context

    # fetch response from OpenAI API
    response = openai.Completion.create(
        engine='text-davinci-002',
        prompt=conversation,
        max_tokens=100,
        n=1,
        stop=None,
        temperature=0.7,
    )

    response_str = response["choices"][0]["text"].replace("\n", "")
    response_str = response_str.split(user_name + ": ", 1)[0].split(bot_name + ": ", 1)[0]

    conversation += response_str + "\n"
    print(response_str)

    bot_text.insert(tk.END, bot_name + ": " + response_str + "\n")
    engine.say(response_str)
    engine.runAndWait()

continue_button.config(command=continue_conversation)

def exit_conversation():
    window.destroy()

exit_button.config(command=exit_conversation)

window.mainloop()

# %% [markdown]
# Youtube video açma versiyonu eklenmiş haline bakalım...

# %%
import openai
import pyttsx3
import speech_recognition as sr
import pywhatkit
import webbrowser
import re

# set up OpenAI API credentials
openai.api_key = "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"

engine = pyttsx3.init()

r = sr.Recognizer()
mic = sr.Microphone(device_index=1)

conversation = ""
user_name = "Simyacı"
bot_name = "PATRON AI"

while True:
    with mic as source:
        print("\nlistening...")
        r.adjust_for_ambient_noise(source, duration=0.2)
        audio = r.listen(source)
    print("no longer listening.\n")

    try:
        user_input = r.recognize_google(audio, language='tr-TR')
        print(user_input)
        if user_input.lower() in ["çıkış", "exit"]:
            break
        elif "youtube'da şu videoyu aç" in user_input.lower():
            # extract the video name from the user input
            video_name = user_input.lower().replace("youtube'da şu videoyu aç", "").strip()
            # play the video using pywhatkit
            pywhatkit.playonyt(video_name)
            continue
    except:
        continue

    prompt = user_name + ": " + user_input + "\n" + bot_name+ ": "

    conversation += prompt  # allows for context

    # fetch response from OpenAI API
    response = openai.Completion.create(
        engine='text-davinci-002',
        prompt=conversation,
        max_tokens=100,
        n=1,
        stop=None,
        temperature=0.7,
    )

    response_str = response["choices"][0]["text"].replace("\n", "")
    response_str = response_str.split(user_name + ": ", 1)[0].split(bot_name + ": ", 1)[0]

    conversation += response_str + "\n"
    print(response_str)

    engine.say(response_str)
    engine.runAndWait()

    if "http" in response_str:
        webbrowser.open_new_tab(response_str)
# Out:
# listening...
# no longer listening.
#
# Merhaba
# Merhaba. Nasıl yardımcı olabilirim?
#
# listening...
# no longer listening.
#
# speak English
# Hello, how can I help you?
#
# listening...
# no longer listening.
#
# iPhone 4 Dead How to Repair
# There are a few things you can try if your iPhone 4 is not responding or has a dead battery. First, try charging the battery. If that doesn't work, try resetting the device by holding down the power and home buttons at the same time for 10 seconds. If neither of those solutions work, you may need to take the device to an Apple Store or an authorized service provider for further diagnosis.
#
# listening...
# no longer listening.
#
# Arabam çalışmıyor Neden
# There are a few possible reasons why your car might not be starting. It could be a problem with the battery, the starter, or something else entirely. If you're not sure what the problem is, the best course of action is to take the car to a mechanic or an authorized service center for diagnosis.
#
# listening...
# no longer listening.
#
#
# listening...
# no longer listening.
#
# blok zincir ne demek
# A block chain is a digital ledger of all cryptocurrency transactions. It is constantly growing as "completed" blocks are added to it with a new set of recordings. Each block contains a cryptographic hash of the previous block, a timestamp, and transaction data. Bitcoin nodes use the block chain to differentiate legitimate Bitcoin transactions from attempts to re-spend coins that have already been spent elsewhere.
#
# listening...
# no longer listening.
#
# sana göre en ilgi çekici site hangisi
# There are a lot of different websites out there, so it really depends on what you're interested in. Some popular options include social media sites like Facebook and Twitter, news sites like CNN and Fox News, and entertainment sites like BuzzFeed and IGN.
#
# listening...
# no longer listening.
#
# bir tanesinin linkini ver
# https://www.facebook.com/
#
# listening...
# no longer listening.
#
#
# listening...
# no longer listening.
#
#
# listening...
# no longer listening.
#
# Fenerbahçe kim
# Fenerbahçe is a Turkish professional football club based in Istanbul. The club was founded in 1907 and has competed in the top level of Turkish football since 1909. Fenerbahçe is one of the most successful clubs in Turkey, having won 19 Turkish Superlig titles, 6 Turkish Cups, and 9 Turkish Super Cups.
#
# listening...
# no longer listening.
#
# Fenerbahçe'nin güncel kadrosunda kimler var
# Fenerbahçe's current squad includes players like goalkeeper Volkan Demirel, defenders Hasan Ali Kaldırım and Simon Kjær, midfielders Josef de Souza and Mehmet Topal, and forwards Robin van Persie and Moussa Sow.
#
# listening...
# no longer listening.
#
# bu bilgiler hangi yıldan
# These details are from the 2017-2018 season.
#
# listening...
# no longer listening.
#
# Senin bilgilerini sınırı hangi yılda
# I don't really have an answer to that question.
#
# listening...
# no longer listening.
#
# senin bilgilerinin sınırını hangi yıl oluşturuyor
# I don't really have an answer to that question.
#
# listening...
# no longer listening.
#
# veritabanındaki en son bilgi kaç yılından
# The most recent information in the database is from the 2017-2018 season.
#
# listening...
# no longer listening.
#
#
# listening...
# no longer listening.
#
# çıkış
